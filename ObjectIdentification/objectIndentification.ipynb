# %%
import pandas as pd
import os

# %%
# 検索対象作品のidと使用されているスプライトのデータセット
dataset = pd.read_csv("/Users/yuki-f/Documents/SocSEL/Research/ObjectIdentification/dataset.csv", usecols=[2, 4])

# %%
# スプライト画像のディレクトリ
spritesPath = "/Users/yuki-f/Documents/SocSEL/Research/ObjectIdentification/sprites"
# スクリーンショットのディレクトリ
screenshotsPath = "/Users/yuki-f/Documents/SocSEL/Research/ObjectIdentification/screenshots"

# %%
for pathName, dirNames, fileNames in os.walk(screenshotsPath):
    print()
    print("pathName: " + pathName)
    for dirName in dirNames:
        print("dirName: " + dirName)
    for fileName in fileNames:
        print("fileName: " + fileName)
# Out:
# pathName: /Users/yuki-f/Documents/SocSEL/Research/ObjectIdentification/screenshots
# dirName: 99158273
# dirName: 99231650
# dirName: 99222247
# dirName: 99236475
# dirName: 99113379
# dirName: 99234110
# dirName: 99149765
# dirName: 99180401
# dirName: 99169362
# dirName: 99158617
# dirName: 99197684
# dirName: 99171369
# dirName: 99143099
# dirName: 99230776
# dirName: 99151138
# dirName: 99173268
# dirName: 99104934
# dirName: 99113983
# dirName: 99111849
# dirName: 99136657
# dirName: 99193029
# dirName: 99158842
# dirName: 99131016
# dirName: 99175968
# dirName: 99163031
# dirName: 99189311
# dirName: 99117520
# dirName: 99104305
# dirName: 99115045
# dirName: 99184258
# dirName: 99109842
# dirName: 99115613
# dirName: 99171356
# dirName: 99153006
# dirName: 99125086
# dirName: 99163693
# dirName: 99118930
# dirName: 99184436
# dirName: 99223154
# dirName: 99247411
# dirName: 99109422
# dirName: 99189927
# dirName: 99201660
# dirName: 99107914
# dirName: 99131678
# ...

# %%
for pathName, dirNames, fileNames in os.walk(screenshotsPath):
    print()
    print("pathName: " + pathName)
    
    # 各検索対象作品ごとにdataset.csvから使われているスプライトを取得する
    for dirName in dirNames:
        # print("dirName: " + dirName)
        print(dataset[dataset["p_ID"] == int(dirName)]["sprite-name"].values)
# Out:
# pathName: /Users/yuki-f/Documents/SocSEL/Research/ObjectIdentification/screenshots
# ['Sprite1']
# []
# []
# ['Snowflake']
# []
# ['Sprite1']
# ['Sprite1']
# ['Sprite1']
# []
# ['Sprite1']
# ['Sprite1']
# []
# ['Cassy Dance' 'Duck']
# []
# []
# ['Pico']
# []
# ['Sprite1']
# []
# ['Ball']
# []
# ['Sprite1']
# ['Sprite1']
# []
# []
# ['Dog2']
# []
# []
# []
# []
# ['Sprite1']
# ['Sprite1']
# []
# []
# []
# []
# ['Sprite1']
# []
# []
# []
# []
# ['Witch']
# []
# ['Sprite1']
# ['Sprite1' 'Gobo']
# ['Sprite1']
# ['Sprite1']
# ['Sprite1']
# []
# ['Sprite1']
# ['Sprite1' 'Avery Walking']
# ['Sprite1' 'Apple']
# []
# ['Sprite1']
# ['Sprite1' 'Dog1']
# ['Sprite1']
# ['Cloud' 'Sun']
# []
# ['Avery Walking']
# []
# ['Parrot']
# ['Snowflake']
# ['Pencil']
# []
# ['Sprite1' 'Ball' 'Jaime']
# ['Sprite1']
# []
# []
# ['Sprite1' 'Button3']
# ['Sprite1']
# []
# ['Sprite1']
# ['Sprite1']
# []
# ['Sprite1' 'Apple']
# []
# ['Sprite1']
# ['Sprite1']
# ['Frog' 'Fruit Platter']
# ['Dog1' 'Dog2']
# ...
