# %%
import pandas as pd

# %%
spritesName = pd.read_csv("/Users/yuki-f/Documents/SocSEL/Research/ObjectIdentification/sprites.csv")

# %%
import os

# %%
spritesPath = "/Users/yuki-f/Documents/SocSEL/Research/ObjectIdentification/Sprites"
spritesNamePath = "/Users/yuki-f/Documents/SocSEL/Research/ObjectIdentification/sprites.csv"
datasetPath = "/Users/yuki-f/Documents/SocSEL/Research/ObjectIdentification/dataset.csv"
screenshotsPath = "/Users/yuki-f/Documents/SocSEL/Research/ObjectIdentification/Screenshots"

# %%
for pathName, dirNames, fileNames in os.walk(spritesPath):
    print()
    print("pathName: " + pathName)
    for dirName in dirNames:
        print("dirName: " + dirName)
    for fileName in fileNames:
        print("fileName: " + fileName)
# Out:
# pathName: /Users/yuki-f/Documents/SocSEL/Research/ObjectIdentification/Sprites
# dirName: Characters 2
# dirName: Apple
# dirName: Glow-2
# dirName: Ten80 Dance
# dirName: Green Flag
# dirName: City Bus
# dirName: Glow-5
# dirName: Scarf
# dirName: Cat
# dirName: Glow-Y
# dirName: Devin
# dirName: Glow-P
# dirName: Centaur
# dirName: Glow-W
# dirName: Dog1
# dirName: Drum-cymbal
# dirName: Cat Flying
# dirName: Glow-E
# dirName: Princess
# dirName: Glow-B
# dirName: Champ99
# dirName: Lightning
# dirName: Diver1
# dirName: Glow-K
# dirName: Glow-L
# dirName: Rocketship
# dirName: Bananas
# dirName: Glow-V
# dirName: Anina Dance
# dirName: Hippo1
# dirName: Strawberry
# dirName: Glow-Q
# dirName: Harper
# dirName: Balloon1
# dirName: Buildings
# dirName: Avery
# dirName: Glow-X
# dirName: Glow-4
# dirName: Sun
# dirName: Pico Walking
# dirName: Guitar-electric1
# dirName: Glow-3
# dirName: Dragonfly
# dirName: Crab
# dirName: Hatchling
# dirName: Dani
# dirName: Glow-M
# ...
